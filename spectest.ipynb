# %%
# Sean Dougherty
# 14/10/2021
# Testing data insertion and visualization in Rubin's jupyterlab
# note that this project exists in the 'myproject-env' virtual environment

# %%
from astropy.io import fits
import matplotlib.pyplot as plt
import numpy as np

# %%
path = '/home/c1029594/Documents/testdata/'

# %%
spectrum = fits.open(path+'spectrum1.fit')

# %%
specg = spectrum[0].data.copy()

# %%
print(type(specg))
print(specg.shape)
print(len(specg[0]))
# Out:
# <class 'numpy.ndarray'>
# (5, 3860)
# 3860

# %%
# plot the spectrum
l = list(range(len(specg[0])))

# %%
plt.plot(l,specg[0])
plt.show()
